# %%
# Loading the configuration for the analysis
# %load_ext autoreload
# %autoreload 2
from eeg_toolkit import (
    load_config,
    compute_tfr_all,
    compute_grand_average_tfr,
)
cfg = load_config('../../configs/eye_eeg_simul.yaml')
cfg_tfr = load_config('../../configs/tfr_analysis.yaml')
print("Setup OK")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Setup OK

# %%
# Computes the time frequency analysis on each subject saving each file in the subject folder
results, trial_counts = compute_tfr_all(cfg, cfg_tfr, overwrite=True)
# Out:
# [find_subjects] excluded 8 subject(s): ['subj13', 'subj15', 'subj16', 'subj17', 'subj2', 'subj20', 'subj28', 'subj7']
# Computing TFRs for 30 subjects
# ...
#
# subj3
#   subj3 [trial]: saved 3 TFRs (subj3_trial_tfr.h5)
#   subj3 [cue]: saved 3 TFRs (subj3_cue_tfr.h5)
#
# subj4
#   subj4 [trial]: saved 3 TFRs (subj4_trial_tfr.h5)
#   subj4 [cue]: saved 3 TFRs (subj4_cue_tfr.h5)
#
# subj5
#   subj5 [trial]: saved 3 TFRs (subj5_trial_tfr.h5)
#   subj5 [cue]: saved 3 TFRs (subj5_cue_tfr.h5)
#
# subj6
#   subj6 [trial]: saved 3 TFRs (subj6_trial_tfr.h5)
#   subj6 [cue]: saved 3 TFRs (subj6_cue_tfr.h5)
#
# subj8
#   subj8 [trial]: saved 3 TFRs (subj8_trial_tfr.h5)
#   subj8 [cue]: saved 3 TFRs (subj8_cue_tfr.h5)
#
# subj10
#   subj10 [trial]: saved 3 TFRs (subj10_trial_tfr.h5)
#   subj10 [cue]: saved 3 TFRs (subj10_cue_tfr.h5)
#
# subj14
#   subj14 [trial]: saved 3 TFRs (subj14_trial_tfr.h5)
#   subj14 [cue]: saved 3 TFRs (subj14_cue_tfr.h5)
#
# subj18
# ...

# %%
# Computes the grand average of all subjects and stores the analysis in the folder group analysis, tfr. 
# In this case this will only save the average, be carefull when wanting to calculate SEM for example.
compute_grand_average_tfr(cfg, cfg_tfr)
# Out:
# [find_subjects] excluded 8 subject(s): ['subj13', 'subj15', 'subj16', 'subj17', 'subj2', 'subj20', 'subj28', 'subj7']
#   [trial] spatial: grand average saved (N=30)
#   [trial] symbolic: grand average saved (N=30)
#   [trial] spatial_vs_symbolic: grand average saved (N=30)
#   [cue] spatial: grand average saved (N=30)
#   [cue] symbolic: grand average saved (N=30)
#   [cue] spatial_vs_symbolic: grand average saved (N=30)
